# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras as K
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
gen1 = K.models.load_model('generator_full_ckp_epoch_50.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
gen1.compile()

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
gen2 = K.models.load_model('generator_full_ckp_epoch_100.h5')
gen3 = K.models.load_model('generator_full_ckp_epoch_150.h5')
gen4 = K.models.load_model('generator_full_ckp_epoch_200.h5')

gen2.compile()
gen3.compile()
gen4.compile()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
plt.imshow(gen4(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen4(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen4(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen4(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen4(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gen1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
genv2_1 = K.models.load_model('generator_full2_ckp_epoch_10.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
genv2_1.compile()

# %%
plt.imshow(genv2_1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_1(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
genv2_2 = K.models.load_model('generator_full2_ckp_epoch_20.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
genv2_2.compile()

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(genv2_2(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
