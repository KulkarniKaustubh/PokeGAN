# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import pickle
import tensorflow as tf
import tensorflow.keras as K
import tensorflow.keras.layers as layers
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
# Out:
# TensorFlow version: 2.2.0
# Eager execution: True

# %%
# loading the dataset
file = open('/content/drive/My Drive/ColabData/pokemon_arrays_5k.pkl', 'rb')
images = pickle.load(file)
file.close()

print("Number of images = " + str(len(images)))
print("Shape of each image = " + str(images[0].shape))
# Out:
# Number of images = 5027
# Shape of each image = (100, 100, 3)

# %%
# reshaping the data
X_train = np.reshape(images, (len(images), 100, 100, 3))

print(X_train.shape)

# print(X_train[0][1])
# Out:
# (5027, 100, 100, 3)

# %%
# normalizing
X_train = X_train/255.
print(X_train.shape)
# print(X_train[0][1])
# Out:
# (5027, 100, 100, 3)

# %%
plt.imshow(X_train[0])

# %%
imageSize = 100

# %%
BUFFER = X_train.shape[0]
BATCH_SIZE = 256      #128

trainingData = tf.data.Dataset.from_tensor_slices(X_train).shuffle(BUFFER).batch(BATCH_SIZE)

# just to check dimensions
lst = list(trainingData.as_numpy_iterator())
print(len(lst))
print(len(lst[0]))
print(len(lst[-1]))
print(len(lst[0][0]))
print(len(lst[0][0][0]))
print(len(lst[0][0][0][0]))
# Out:
# 20
# 256
# 163
# 100
# 100
# 3

# %% [markdown]
# # Models
# - Discriminator model
# - Generator model

# %%
K.backend.clear_session()

def getDiscriminatorModel():
    model = K.models.Sequential([
        layers.Conv2D(32, (3, 3), padding = 'same', input_shape = (imageSize, imageSize, 3)),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        
        layers.Conv2D(64, (3, 3), strides = (2, 2), padding = 'same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        
        layers.Conv2D(128, (3, 3), strides = (2, 2), padding = 'same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(),

        layers.Conv2D(256, (3, 3), padding = 'same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        
        layers.Flatten(),
        layers.Dense(512),
        layers.LeakyReLU(),

        layers.Dense(1),
        layers.Activation('sigmoid')
    ])
    
    return model

# %%
discriminator = getDiscriminatorModel()

# %%
discriminator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100, 100, 32)      128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 256)       1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 25, 25, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 160000)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               81920512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 82,311,361
# Trainable params: 82,310,401
# Non-trainable params: 960
# _________________________________________________________________

# %%
# from the summary above, we see that we get a 25x25x128 just before flattenning
genSize = 25
depth = 256    #128

def getGeneratorModel():
    model = K.models.Sequential([
        layers.Dense(genSize*genSize*depth, input_shape = (100,)),
        
        # shouldn't explode
        layers.BatchNormalization(),
        layers.Reshape((genSize, genSize, depth)),
        layers.LeakyReLU(),

        layers.Conv2DTranspose(256, (3, 3), padding = 'same'),
        layers.LeakyReLU(),
        
        layers.Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same'),
        layers.LeakyReLU(),
        
        layers.Conv2DTranspose(64, (3, 3), padding = 'same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        
        layers.Conv2DTranspose(32, (3, 3), strides = (2, 2), padding = 'same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        
        # at this point the image is upsampled twice so we get the original image size
        layers.Conv2DTranspose(3, (3, 3), padding = 'same'),
        layers.Activation('tanh')
    ])
    
    return model

# %%
generator = getGeneratorModel()

# %%
generator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 160000)            16160000
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 160000)            640000
# _________________________________________________________________
# reshape (Reshape)            (None, 25, 25, 256)       0
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 25, 25, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 25, 25, 256)       590080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 25, 25, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 50, 50, 128)       295040
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 50, 50, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 50, 50, 64)        73792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 100, 100, 32)      18464
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 100, 100, 3)       867
# _________________________________________________________________
# activation_1 (Activation)    (None, 100, 100, 3)       0
# =================================================================
# Total params: 17,778,627
# Trainable params: 17,458,435
# Non-trainable params: 320,192
# _________________________________________________________________

# %%
# testing the generator with some noise
noise = tf.random.normal([1, 100])
genImg = generator(noise, training = False)
print(genImg.shape)
# Out:
# (1, 100, 100, 3)

# %%
plt.imshow(genImg[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Optimizers

# %%
genOpt = K.optimizers.Adam(lr = 2e-4, beta_1 = 0.5)   # lr = 1e-4
discOpt = K.optimizers.SGD(lr = 1e-4, momentum = 0.1)   # default beta_1 = 0.0

# %% [markdown]
# # Losses

# %%
def getGeneratorLoss(fakePreds):
    # adding real prediction loss for generator as well and seeing how it performs
    # note - did not perform well
    # losses flipped in discriminator
    # rLoss = K.losses.BinaryCrossentropy()(tf.zeros_like(realPreds), realPreds)
    # fLoss = K.losses.BinaryCrossentropy()(tf.ones_like(fakePreds), fakePreds)
    # totalLoss = rLoss + fLoss
    return K.losses.BinaryCrossentropy()(tf.ones_like(fakePreds), fakePreds)
    # return totalLoss

# %%
def getDiscriminatorLoss(realPreds, fakePreds):
    rLoss = K.losses.BinaryCrossentropy()(tf.ones_like(realPreds), realPreds)
    fLoss = K.losses.BinaryCrossentropy()(tf.zeros_like(fakePreds), fakePreds)
    totalLoss = rLoss + fLoss
    return totalLoss

# %% [markdown]
# # Training

# %%
EPOCHS = 200        # 50

# %%
genLoss = []
discLoss = []

def train(dataset, epochs):

    gLoss = None
    dLoss = None

    for epoch in range(epochs):

        for pokemon in dataset:
            gLoss, dLoss = trainStep(pokemon)
        
        genLoss.append(gLoss)
        discLoss.append(dLoss)

        print("Running epoch : " + str(epoch + 1))

        if (epoch+1)%5 == 0:
          print("Generator loss : " + str(gLoss))
          print("Discriminator loss : " + str(dLoss))

# %%
# this decorator is used to 
@tf.function
def trainStep(images):
    noise = tf.random.normal([BATCH_SIZE, 100])
    
    with tf.GradientTape() as gen, tf.GradientTape() as disc:
        genImages = generator(noise, training = True)
        
        realOP = discriminator(images, training = True)
        fakeOP = discriminator(genImages, training = True)
        
        genLoss = getGeneratorLoss(fakeOP)
        discLoss = getDiscriminatorLoss(realOP, fakeOP)
        
    genGrads = gen.gradient(genLoss, generator.trainable_variables)
    discGrads = disc.gradient(discLoss, discriminator.trainable_variables)
    
    genOpt.apply_gradients(zip(genGrads, generator.trainable_variables))
    discOpt.apply_gradients(zip(discGrads, discriminator.trainable_variables))

    return genLoss, discLoss

# %%
train(trainingData, EPOCHS)
# Out:
# Running epoch : 1
# Running epoch : 2
# Running epoch : 3
# Running epoch : 4
# Running epoch : 5
# Generator loss : tf.Tensor(0.009214, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(8.366291, shape=(), dtype=float32)
# Running epoch : 6
# Running epoch : 7
# Running epoch : 8
# Running epoch : 9
# Running epoch : 10
# Generator loss : tf.Tensor(0.023983639, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(8.853259, shape=(), dtype=float32)
# Running epoch : 11
# Running epoch : 12
# Running epoch : 13
# Running epoch : 14
# Running epoch : 15
# Generator loss : tf.Tensor(0.09718061, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(6.099556, shape=(), dtype=float32)
# Running epoch : 16
# Running epoch : 17
# Running epoch : 18
# Running epoch : 19
# Running epoch : 20
# Generator loss : tf.Tensor(0.13489737, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(6.066204, shape=(), dtype=float32)
# Running epoch : 21
# Running epoch : 22
# Running epoch : 23
# Running epoch : 24
# Running epoch : 25
# Generator loss : tf.Tensor(0.14191893, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(5.995346, shape=(), dtype=float32)
# Running epoch : 26
# Running epoch : 27
# Running epoch : 28
# Running epoch : 29
# Running epoch : 30
# Generator loss : tf.Tensor(0.14396557, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(4.8527102, shape=(), dtype=float32)
# Running epoch : 31
# Running epoch : 32
# Running epoch : 33
# Running epoch : 34
# Running epoch : 35
# Generator loss : tf.Tensor(0.18588857, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(4.057932, shape=(), dtype=float32)
# Running epoch : 36
# Running epoch : 37
# Running epoch : 38
# Running epoch : 39
# Running epoch : 40
# Generator loss : tf.Tensor(0.24266422, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(3.7256973, shape=(), dtype=float32)
# Running epoch : 41
# Running epoch : 42
# Running epoch : 43
# Running epoch : 44
# Running epoch : 45
# Generator loss : tf.Tensor(0.25488958, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(3.341076, shape=(), dtype=float32)
# Running epoch : 46
# Running epoch : 47
# Running epoch : 48
# Running epoch : 49
# Running epoch : 50
# Generator loss : tf.Tensor(0.2844958, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(3.1560698, shape=(), dtype=float32)
# Running epoch : 51
# Running epoch : 52
# Running epoch : 53
# Running epoch : 54
# Running epoch : 55
# Generator loss : tf.Tensor(0.30398604, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.8424416, shape=(), dtype=float32)
# Running epoch : 56
# Running epoch : 57
# Running epoch : 58
# Running epoch : 59
# Running epoch : 60
# Generator loss : tf.Tensor(0.32684863, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.7781134, shape=(), dtype=float32)
# Running epoch : 61
# Running epoch : 62
# Running epoch : 63
# Running epoch : 64
# Running epoch : 65
# Generator loss : tf.Tensor(0.35416833, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.6714253, shape=(), dtype=float32)
# Running epoch : 66
# Running epoch : 67
# Running epoch : 68
# Running epoch : 69
# Running epoch : 70
# Generator loss : tf.Tensor(0.37506604, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.4713497, shape=(), dtype=float32)
# Running epoch : 71
# Running epoch : 72
# Running epoch : 73
# Running epoch : 74
# Running epoch : 75
# Generator loss : tf.Tensor(0.3835997, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.40232, shape=(), dtype=float32)
# Running epoch : 76
# Running epoch : 77
# Running epoch : 78
# Running epoch : 79
# Running epoch : 80
# Generator loss : tf.Tensor(0.39564276, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.3212905, shape=(), dtype=float32)
# Running epoch : 81
# Running epoch : 82
# Running epoch : 83
# Running epoch : 84
# Running epoch : 85
# Generator loss : tf.Tensor(0.40081793, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.2881584, shape=(), dtype=float32)
# Running epoch : 86
# Running epoch : 87
# Running epoch : 88
# Running epoch : 89
# Running epoch : 90
# Generator loss : tf.Tensor(0.4325572, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.1595001, shape=(), dtype=float32)
# Running epoch : 91
# Running epoch : 92
# Running epoch : 93
# Running epoch : 94
# Running epoch : 95
# Generator loss : tf.Tensor(0.43041155, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.1793582, shape=(), dtype=float32)
# Running epoch : 96
# Running epoch : 97
# Running epoch : 98
# Running epoch : 99
# Running epoch : 100
# Generator loss : tf.Tensor(0.4067014, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.152563, shape=(), dtype=float32)
# Running epoch : 101
# Running epoch : 102
# Running epoch : 103
# Running epoch : 104
# Running epoch : 105
# Generator loss : tf.Tensor(0.35948852, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.1617718, shape=(), dtype=float32)
# Running epoch : 106
# Running epoch : 107
# Running epoch : 108
# Running epoch : 109
# Running epoch : 110
# Generator loss : tf.Tensor(0.7725578, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.4313388, shape=(), dtype=float32)
# Running epoch : 111
# Running epoch : 112
# Running epoch : 113
# Running epoch : 114
# Running epoch : 115
# Generator loss : tf.Tensor(0.50619125, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.6199882, shape=(), dtype=float32)
# Running epoch : 116
# Running epoch : 117
# Running epoch : 118
# Running epoch : 119
# Running epoch : 120
# Generator loss : tf.Tensor(0.7207123, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.2433417, shape=(), dtype=float32)
# Running epoch : 121
# Running epoch : 122
# Running epoch : 123
# Running epoch : 124
# Running epoch : 125
# Generator loss : tf.Tensor(0.5571758, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7207354, shape=(), dtype=float32)
# Running epoch : 126
# Running epoch : 127
# Running epoch : 128
# Running epoch : 129
# Running epoch : 130
# Generator loss : tf.Tensor(0.5609713, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.8108732, shape=(), dtype=float32)
# Running epoch : 131
# Running epoch : 132
# Running epoch : 133
# Running epoch : 134
# Running epoch : 135
# Generator loss : tf.Tensor(0.5252205, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.869041, shape=(), dtype=float32)
# Running epoch : 136
# Running epoch : 137
# Running epoch : 138
# Running epoch : 139
# Running epoch : 140
# Generator loss : tf.Tensor(0.47194654, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(2.1082788, shape=(), dtype=float32)
# Running epoch : 141
# Running epoch : 142
# Running epoch : 143
# Running epoch : 144
# Running epoch : 145
# Generator loss : tf.Tensor(0.51191425, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.9306307, shape=(), dtype=float32)
# Running epoch : 146
# Running epoch : 147
# Running epoch : 148
# Running epoch : 149
# Running epoch : 150
# Generator loss : tf.Tensor(0.5586978, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.818121, shape=(), dtype=float32)
# Running epoch : 151
# Running epoch : 152
# Running epoch : 153
# Running epoch : 154
# Running epoch : 155
# Generator loss : tf.Tensor(0.5628244, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7610345, shape=(), dtype=float32)
# Running epoch : 156
# Running epoch : 157
# Running epoch : 158
# Running epoch : 159
# Running epoch : 160
# Generator loss : tf.Tensor(0.5460352, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7946132, shape=(), dtype=float32)
# Running epoch : 161
# Running epoch : 162
# Running epoch : 163
# Running epoch : 164
# Running epoch : 165
# Generator loss : tf.Tensor(0.5544396, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7625322, shape=(), dtype=float32)
# Running epoch : 166
# Running epoch : 167
# Running epoch : 168
# Running epoch : 169
# Running epoch : 170
# Generator loss : tf.Tensor(0.5452381, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7354019, shape=(), dtype=float32)
# Running epoch : 171
# Running epoch : 172
# Running epoch : 173
# Running epoch : 174
# Running epoch : 175
# Generator loss : tf.Tensor(0.53266644, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.778225, shape=(), dtype=float32)
# Running epoch : 176
# Running epoch : 177
# Running epoch : 178
# Running epoch : 179
# Running epoch : 180
# Generator loss : tf.Tensor(0.53643507, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7903123, shape=(), dtype=float32)
# Running epoch : 181
# Running epoch : 182
# Running epoch : 183
# Running epoch : 184
# Running epoch : 185
# Generator loss : tf.Tensor(0.54270166, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7549566, shape=(), dtype=float32)
# Running epoch : 186
# Running epoch : 187
# Running epoch : 188
# Running epoch : 189
# Running epoch : 190
# Generator loss : tf.Tensor(0.55632097, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7403529, shape=(), dtype=float32)
# Running epoch : 191
# Running epoch : 192
# Running epoch : 193
# Running epoch : 194
# Running epoch : 195
# Generator loss : tf.Tensor(0.5604111, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7089313, shape=(), dtype=float32)
# Running epoch : 196
# Running epoch : 197
# Running epoch : 198
# Running epoch : 199
# Running epoch : 200
# Generator loss : tf.Tensor(0.5554334, shape=(), dtype=float32)
# Discriminator loss : tf.Tensor(1.7089193, shape=(), dtype=float32)

# %%
plt.plot(range(EPOCHS), genLoss, label = "Generator loss")
plt.plot(range(EPOCHS), discLoss, label = "Discriminator loss")
plt.legend()
plt.title('Losses')
plt.show()

# %%
plt.imshow(generator(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(generator(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(generator(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(generator(tf.random.normal([1, 100]))[0, :, :, :])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
generator.save('generator_50ep_adam_lr0.00001_b10.5.h5')
discriminator.save('discriminator_50ep_adam_lr0.00001_b10.5_sgd_lr0.00001.h5')
